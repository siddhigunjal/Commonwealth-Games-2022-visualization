# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('medals.csv')

# %%
df.head()
# Out:
#      ATHLETE NAME       TEAM                           SPORT          EVENT  \
# 0    Aaron Wilson  Australia  Lawn Bowls and Para Lawn Bowls  Men's Singles
# 1  Abbey Caldwell  Australia    Athletics and Para Athletics  Women's 1500m
# 2  Abigail Paduch  Australia                            Judo   Women +78 kg
# 3      Alana King  Australia                     Cricket T20    Cricket T20
# 4   Aleisha Power  Australia                          Hockey          Women
#
#   MEDAL           CONTINENT EVENT TYPE
# 0     G  Australia& Oceania     Single
# 1     B  Australia& Oceania     Single
# 2     B  Australia& Oceania     Single
# 3     G  Australia& Oceania      Mixed
# 4     S  Australia& Oceania      Mixed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1558 entries, 0 to 1557
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ATHLETE NAME  1558 non-null   object
#  1   TEAM          1558 non-null   object
#  2   SPORT         1558 non-null   object
#  3   EVENT         1558 non-null   object
#  4   MEDAL         1558 non-null   object
#  5   CONTINENT     1558 non-null   object
#  6   EVENT TYPE    1558 non-null   object
# dtypes: object(7)
# memory usage: 85.3+ KB

# %%
df.isnull().sum()
# Out:
# ATHLETE NAME    0
# TEAM            0
# SPORT           0
# EVENT           0
# MEDAL           0
# CONTINENT       0
# EVENT TYPE      0
# dtype: int64

# %%
#How many types of events are there
df['EVENT TYPE'].value_counts()
# Out:
# Mixed     863
# Single    695
# Name: EVENT TYPE, dtype: int64

# %% [markdown]
# Their are total 2 types of events Mixed 863 and Single 695

# %%
#Top 5 country having most athlets
df['TEAM'].value_counts().head().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Top 5 country having most athlets are
# Australia      336
# England        327
# Canada         155
# India          132
# New Zealand    116

# %%
#How many gold medals does team india got
df['TEAM'].loc[(df['TEAM']=='India')&(df['MEDAL']=='G')].value_counts()
# Out:
# India    30
# Name: TEAM, dtype: int64

# %% [markdown]
# Team India got 30 gold medals

# %%
df['SPORT'].value_counts()
# Out:
# Aquatics - Swimming and Para Swimming    274
# Athletics and Para Athletics             231
# Hockey                                   108
# Cycling - Track and Para Track            91
# Lawn Bowls and Para Lawn Bowls            84
# Rugby Sevens                              78
# Gymnastics - Artistic                     66
# Boxing                                    64
# Table Tennis and Para Table Tennis        60
# Judo                                      56
# Badminton                                 54
# Aquatics - Diving                         54
# Weightlifting                             48
# Wrestling                                 45
# Cricket T20                               45
# Netball                                   36
# 3x3 Basketball                            24
# Gymnastics - Rhythmic                     24
# Triathlon and Para Triathlon              24
# Squash                                    24
# 3x3 Wheelchair Basketball                 23
# ...

# %% [markdown]
# Most participants were in Aquatics - Swimming and Para Swimming that in 274

# %%
df['EVENT'].value_counts()
# Out:
# Women                              123
# Men                                122
# Cricket T20                         45
# Netball                             36
# Mixed Team Event                    30
#                                   ...
# Men's 50m Freestyle S7               3
# Men's Sprint                         3
# Men's Discus Throw F42-44/61-64      3
# Women's Freestyle 53 kg              2
# Women's T53/54 Marathon              2
# Name: EVENT, Length: 258, dtype: int64

# %% [markdown]
# most events played were by Women

# %%
df.head()
# Out:
#      ATHLETE NAME       TEAM                           SPORT          EVENT  \
# 0    Aaron Wilson  Australia  Lawn Bowls and Para Lawn Bowls  Men's Singles
# 1  Abbey Caldwell  Australia    Athletics and Para Athletics  Women's 1500m
# 2  Abigail Paduch  Australia                            Judo   Women +78 kg
# 3      Alana King  Australia                     Cricket T20    Cricket T20
# 4   Aleisha Power  Australia                          Hockey          Women
#
#   MEDAL           CONTINENT EVENT TYPE
# 0     G  Australia& Oceania     Single
# 1     B  Australia& Oceania     Single
# 2     B  Australia& Oceania     Single
# 3     G  Australia& Oceania      Mixed
# 4     S  Australia& Oceania      Mixed

# %%
t=df.groupby('TEAM')

# %%
t.first()
# Out:
#                                      ATHLETE NAME  \
# TEAM
# Australia                            Aaron Wilson
# Barbados                           Jonathan Jones
# Bermuda                               Flora Duffy
# Botswana                           Anthony Pesela
# British Virgin Is.                 Kyron McMaster
# Cameroon                       Arlette Mawe Fokoa
# Canada                                 Adam Paige
# Cyprus                     Alexandros Poursanidis
# Dominica                              Thea Lafond
# England                               Aaron Bowen
# Fiji                              Adi Vani Buleki
# Ghana                            Abdul Wahib Omar
# Grenada                           Anderson Peters
# Guernsey                        Alastair Chalmers
# India                                    . Sudhir
# Jamaica                      Adean Tamesha Thomas
# Kenya                             Abraham Kibiwot
# Malaysia                               Ai Xin Tee
# ...

# %%
b=t.get_group('India')

# %%
b
# Out:
#                              ATHLETE NAME   TEAM  \
# 887                              . Sudhir  India
# 888                      Aakarshi Kashyap  India
# 889   Abdulla Aboobacker Narangolintevida  India
# 890                        Achinta Sheuli  India
# 891                                  AMIT  India
# ...                                   ...    ...
# 1014                         Vikas Thakur  India
# 1015                        Vinesh Phogat  India
# 1016                   Vivek Sagar Prasad  India
# 1017                       Yastika Bhatia  India
# 1018                        Zareen Nikhat  India
#
#                              SPORT                                     EVENT  \
# 887              Para Powerlifting                         Men's Heavyweight
# 888                      Badminton                          Mixed Team Event
# 889   Athletics and Para Athletics                         Men's Triple Jump
# ...

# %%
b[['ATHLETE NAME','SPORT']].loc[b['ATHLETE NAME']=='Vinesh Phogat']
# Out:
#        ATHLETE NAME      SPORT
# 1015  Vinesh Phogat  Wrestling

# %%
(b[['ATHLETE NAME','MEDAL']].loc[b['MEDAL']==b['MEDAL']]).value_counts()
# Out:
# ATHLETE NAME           MEDAL
# Sharath Kamal Achanta  G        3
# Saurav Ghosal          B        2
# . Sudhir               G        1
# Pooja Vastrakar        S        1
# Singh Hardik           S        1
#                                ..
# Jyoti                  B        1
# Jemimah Rodrigues      S        1
# Jaismine Jaismine      B        1
# Hussam Uddin Mohammed  B        1
# Zareen Nikhat          G        1
# Length: 129, dtype: int64

# %% [markdown]
# We can see that most medals won are gold by Sharath Kamal Achanta in INDIA

# %%
b['MEDAL'].value_counts()
# Out:
# S    60
# B    42
# G    30
# Name: MEDAL, dtype: int64

# %% [markdown]
# Here we can see INDIA have got 60 ssilver, 42 bronze and 30 gold medals

# %%
sns.countplot(x='EVENT TYPE',data=b)
# Out:
# <AxesSubplot:xlabel='EVENT TYPE', ylabel='count'>

# %%
plt.figure(figsize=(15,15))
b['EVENT'].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>
